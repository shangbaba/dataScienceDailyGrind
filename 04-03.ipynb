# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import pylab as plt
import seaborn as sb
from IPython.display import Image
from IPython.core.display import HTML
from pylab import rcParams

import sklearn
from sklearn import decomposition
from sklearn.decomposition import PCA
from sklearn import datasets

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('darkgrid')

# %%
iris = datasets.load_iris()
x = iris.data
variable_names = iris.feature_names
df = pd.DataFrame(x, columns = variable_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
pca = decomposition.PCA()
iris_pca = pca.fit_transform(x)
pca.explained_variance_ratio_
# Out:
# array([0.92461621, 0.05301557, 0.01718514, 0.00518309])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 1.0

# %%
abc = decomposition.PCA()
abc
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
iris_abc = abc.fit_transform(x[:10])
abc.explained_variance_ratio_
abc
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
abc.explained_variance_ratio_.sum()
# Out:
# 0.9999999999999999

# %%
xyz = decomposition.PCA()
eye_cde = xyz.fit_transform(x)
xyz.explained_variance_ratio_
# Out:
# array([0.92461621, 0.05301557, 0.01718514, 0.00518309])

# %%
opq = decomposition.PCA()

# %%
opq.fit_transform(x)
# Out:
# array([[-2.68420713e+00,  3.26607315e-01, -2.15118370e-02,
#          1.00615724e-03],
#        [-2.71539062e+00, -1.69556848e-01, -2.03521425e-01,
#          9.96024240e-02],
#        [-2.88981954e+00, -1.37345610e-01,  2.47092410e-02,
#          1.93045428e-02],
#        [-2.74643720e+00, -3.11124316e-01,  3.76719753e-02,
#         -7.59552741e-02],
#        [-2.72859298e+00,  3.33924564e-01,  9.62296998e-02,
#         -6.31287327e-02],
#        [-2.27989736e+00,  7.47782713e-01,  1.74325619e-01,
#         -2.71468037e-02],
#        [-2.82089068e+00, -8.21045110e-02,  2.64251085e-01,
#         -5.00996251e-02],
#        [-2.62648199e+00,  1.70405349e-01, -1.58015103e-02,
#         -4.62817610e-02],
#        [-2.88795857e+00, -5.70798026e-01,  2.73354061e-02,
#         -2.66154143e-02],
#        [-2.67384469e+00, -1.06691704e-01, -1.91533300e-01,
#         -5.58909660e-02],
#        [-2.50652679e+00,  6.51935014e-01, -6.92749958e-02,
#         -1.66082478e-02],
# ...

# %%
opq.ratio_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-96909acf168f> in <module>()
# ----> 1 opq.ratio_
#
# AttributeError: 'PCA' object has no attribute 'ratio_'

# %%
comps = pd.DataFrame(pca.components_, index = variable_names, columns = variable_names)
comps
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           0.361590         -0.082269           0.856572
# sepal width (cm)            0.656540          0.729712          -0.175767
# petal length (cm)          -0.580997          0.596418           0.072524
# petal width (cm)            0.317255         -0.324094          -0.479719
#
#                    petal width (cm)
# sepal length (cm)          0.358844
# sepal width (cm)          -0.074706
# petal length (cm)          0.549061
# petal width (cm)           0.751121

# %%
sb.heatmap(comps)
